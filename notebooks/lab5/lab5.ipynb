# %%
# %%file app.py
from flask import Flask

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
# Out:
# Writing app.py

# %%
# @app.route("/")  to dekorator pythonowy - ma za zadanie uruchomić funkcję pod spodem 
# if __name__ == "__main__": - Wykonaj poniższy kod tylko wtedy, gdy ten plik jest uruchamiany bezpośrednio, a nie importowany.
   # app.run(host="0.0.0.0", port=5000)

# %%
import requests # pozwala wygenerować odpowiedź

response1 = requests.get("http://localhost:5000/")

# %%
import requests # pozwala wygenerować odpowiedź

response = requests.get("http://sebastianzajac.pl/")

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>Sebastian Zając, PhD | Quantum Data Science & Information Field Theory</title>
#
#     <meta name="description"
#       content="PhD Sebastian Zając (SGH) – Researcher in Quantum Data Science and creator of Quantum Information Field Theory. Expert in QML, MLOps (Python/Julia), and Quantum Anomaly Detection for business.">
#     <meta name="keywords" content="Quantum Machine Learning, QML, Quantum Information Field Theory, QIFT, Data Science, MLOps, Julia, Python, Anomaly Detection, SGH, Sebastian Zając">
#     <meta name="author" content="Sebastian Zając">
#     <meta name="robots" content="index,follow" />
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <meta property="og:title" content="Sebastian Zając, PhD | Quantum Data Science & QIFT">
# ...

# %%
print(response1.text)
# Out:
# Witaj w systemie monitoringu transakcji!

# %%
import subprocess, time

server = subprocess.Popen(["python", "app.py"])

time.sleep(2)  # daj serwerowi chwile na start

# %%
import requests

response = requests.get("http://localhost:5000/")
print(f"Status: {response.status_code}")
print(f"Treść: {response.text}")
# Out:
# Status: 200
# Treść: Witaj w systemie monitoringu transakcji!

# %%
server.kill()

# %%
# %%file app.py
from flask import Flask

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

@app.route("/hello")                      
def home():
    return "Hello, world!"

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)

# %%
# %%file app.py
from flask import Flask

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

@app.route("/hello")                      
def abc():
    name = request.args.get("name", "nieznajomy")
    return f"Hello, {name}"

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)

# %%
import requests

dane_do_wyslania = {"a": 34, "b": 2.3}

response = requests.get("http://localhost:5000/suma")
print(f"Status: {response.status_code}")
print(f"Treść: {response.text}")
# Out:
# Status: 404
# Treść: <!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>

# %%
# %%file app.py
from flask import Flask

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

@app.route("/hello")                      
def abc():
    a = request.args.get("a", 0, float)
    b = request.args.get("b", 0, float)
    return f"suma {a} i {b} wynosi {a+b}"

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
# Out:
# Writing app.py

# %%
# %%file app.py
from flask import Flask, request, json

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

@app.route("/suma")                      
def abc():
    a = request.args.get("a", 0, float)
    b = request.args.get("b", 0, float)
    wynik = {"dane":(a,b), "suma": a+b}
    return jsonify(wynik)

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)

# %%
# %%file app.py
from flask import Flask, request, json

app = Flask(__name__)

@app.route("/")                      # adres URL: http://localhost:5000/
def home():
    return "Witaj w systemie monitoringu transakcji!"

@app.route("/iloczyn", methods = ['POST'])                      
def iloczyn():
    dane = request.get_json()
    a = dane.get("a", 0)
    b = dane.get("b", 0)
    wynik = {"dane":(a,b), "iloczyn": a*b}
    return jsonify(wynik)

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)

# %%
# mam 2 sposoby wysylania danych do serwisu - albo metoda get i dane wtedy w adresie albo tworze moje dane i wysylam jako obiekt jsonowy

# %%
import requests

response = requests.post("http://localhost:5000/iloczyn", json=dane_do_wyslania)
print(f"Status: {response.status_code}")
print(f"Treść: {response.text}")
